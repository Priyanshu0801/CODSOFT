# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\user\Documents\IMDb Movies India.csv", encoding='latin1')
data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %%
# Display top 10 rows of dataset
data.head(10)
# Out:
#                                  Name    Year Duration  \
# 0                                         NaN      NaN
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 2                         #Homecoming  (2021)   90 min
# 3                             #Yaaram  (2019)  110 min
# 4                   ...And Once Again  (2010)  105 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 7                      .in for Motion  (2008)   59 min
# 8                  ?: A Question Mark  (2012)   82 min
# 9                            @Andheri  (2014)  116 min
#
#                        Genre  Rating  Votes            Director  \
# 0                      Drama     NaN    NaN       J.S. Randhawa
# 1                      Drama     7.0      8       Gaurav Bakshi
# 2             Drama, Musical     NaN    NaN  Soumyajit Majumdar
# 3            Comedy, Romance     4.4     35          Ovais Khan
# ...

# %%
# Check the last 10 rows of dataset
data.tail(10)
# Out:
#                       Name    Year Duration                 Genre  Rating  \
# 15499        Zulm Ka Jawab  (1995)      NaN                Action     NaN
# 15500      Zulm Ka Muqabla  (1993)      NaN                Action     NaN
# 15501      Zulm Ki Hukumat  (1992)      NaN  Action, Crime, Drama     5.3
# 15502        Zulm Ki Pukar  (1979)      NaN                Action     NaN
# 15503      Zulm Ki Zanjeer  (1989)  125 min  Action, Crime, Drama     5.8
# 15504  Zulm Ko Jala Doonga  (1988)      NaN                Action     4.6
# 15505                Zulmi  (1999)  129 min         Action, Drama     4.5
# 15506            Zulmi Raj  (2005)      NaN                Action     NaN
# 15507        Zulmi Shikari  (1988)      NaN                Action     NaN
# 15508         Zulm-O-Sitam  (1998)  130 min         Action, Drama     6.2
#
#       Votes           Director                Actor 1              Actor 2  \
# 15499   NaN    Surinder Kapoor            Goga Kapoor        Shakti Kapoor
# ...

# %%
# Find the shape of our dataset
data.shape
# Out:
# (15509, 10)

# %%
print("Number of Rows",data.shape[0])
print("Number of column",data.shape[1])
# Out:
# Number of Rows 15509
# Number of column 10

# %%
# Getting Information about our dataset like total numbers rows,Total number of columns, datatypes of each column and memory requirment

data.info
# Out:
# <bound method DataFrame.info of                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %%
#checking the missing value of dataset
print("Any missing value",data.isnull().values.any())
# Out:
# Any missing value True

# %%
data.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
per_missing = data.isnull().sum() * 100 / len(data)
per_missing
# Out:
# Name         0.000000
# Year         3.404475
# Duration    53.317429
# Genre       12.102650
# Rating      48.939326
# Votes       48.932878
# Director     3.385131
# Actor 1     10.426204
# Actor 2     15.371720
# Actor 3     20.272100
# dtype: float64

# %%
#drop all the missing value
data.dropna(axis=0)
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                                 #Yaaram  (2019)  110 min
# 5                    ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                               ...Yahaan  (2005)  142 min
# 8                      ?: A Question Mark  (2012)   82 min
# ...                                   ...     ...      ...
# 15493                              Zubaan  (2015)  115 min
# 15494                            Zubeidaa  (2001)  153 min
# 15503                     Zulm Ki Zanjeer  (1989)  125 min
# 15505                               Zulmi  (1999)  129 min
# 15508                        Zulm-O-Sitam  (1998)  130 min
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# ...

# %%
#check the duplicate value
dup_data=data.duplicated().any()
print("Are there any duplicate value?",dup_data)
# Out:
# Are there any duplicate value? True

# %%
data=data.drop_duplicates()
data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %%
#Get overall statistics about the dataframe
data.describe(include='all')
# Out:
#           Name    Year Duration  Genre       Rating Votes      Director  \
# count    15503   14976     7239  13627  7919.000000  7920         14979
# unique   13838     102      182    485          NaN  2034          5938
# top     Anjaam  (2019)  120 min  Drama          NaN     8  Jayant Desai
# freq         7     408      240   2779          NaN   227            58
# mean       NaN     NaN      NaN    NaN     5.841621   NaN           NaN
# std        NaN     NaN      NaN    NaN     1.381777   NaN           NaN
# min        NaN     NaN      NaN    NaN     1.100000   NaN           NaN
# 25%        NaN     NaN      NaN    NaN     4.900000   NaN           NaN
# 50%        NaN     NaN      NaN    NaN     6.000000   NaN           NaN
# 75%        NaN     NaN      NaN    NaN     6.800000   NaN           NaN
# max        NaN     NaN      NaN    NaN    10.000000   NaN           NaN
#
#             Actor 1 Actor 2 Actor 3
# count         13888   13122   12363
# ...

# %%
#display title of the Movie Having Runtime>=180 minute
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
sns.barplot(x='Year',y='Votes',data=data)
plt.title("Votes by year")
# Out:
# Text(0.5, 1.0, 'Votes by year')

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
data.groupby('Director')['Rating'].mean().sort_values()
# Out:
# Director
# Pramod Mandloi      1.7
# Raajeev Walia       1.8
# Stanley D'Costa     1.8
# Sumeer Sabharwal    1.9
# Rajesh Bajaj        1.9
#                    ...
# Zia Khan Lodhi      NaN
# Zia-ur-Rasheed      NaN
# Zohra               NaN
# Zubeida             NaN
# Zul Vellani         NaN
# Name: Rating, Length: 5938, dtype: float64

# %%
# Numberr of movies per year 
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
data['Year'].value_counts()
# Out:
# Year
# (2019)    408
# (2021)    392
# (2018)    381
# (2017)    360
# (2005)    346
#          ...
# (1922)      1
# (1913)      1
# (1926)      1
# (1914)      1
# (1924)      1
# Name: count, Length: 102, dtype: int64

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
data.groupby('Year')['Rating'].mean()
# Out:
# Year
# (1913)         NaN
# (1914)         NaN
# (1915)         NaN
# (1917)    6.700000
# (1922)         NaN
#             ...
# (2018)    6.239912
# (2019)    6.317671
# (2020)    6.282635
# (2021)    6.625641
# (2022)         NaN
# Name: Rating, Length: 102, dtype: float64

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')
